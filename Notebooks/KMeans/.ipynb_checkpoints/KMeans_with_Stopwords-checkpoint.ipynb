# %% [markdown]
# # Imports

# %%
# Import necessary libraries
from copy import deepcopy
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from matplotlib import pyplot as plt

# %matplotlib inline
from sklearn.cluster import KMeans 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize
from sklearn.metrics import pairwise_distances
import itertools
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn import manifold
import sklearn.datasets 
from sklearn.preprocessing import normalize

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("../../Datensaetze/news_POS_POS_tags_nouns_adjectives_verb.csv")

# %%
df.head(5)
# Out:
#    category filename                              title  \
# 0  business  001.txt  Ad sales boost Time Warner profit
# 1  business  002.txt   Dollar gains on Greenspan speech
# 2  business  003.txt  Yukos unit buyer faces loan claim
# 3  business  004.txt  High fuel prices hit BA's profits
# 4  business  005.txt  Pernod takeover talk lifts Domecq
#
#                                              content  number_of_tokens  \
# 0   Quarterly profits at US media giant TimeWarne...             415.0
# 1   The dollar has hit its highest level against ...             379.0
# 2   The owners of embattled Russian oil giant Yuk...             258.0
# 3   British Airways has blamed high fuel prices f...             400.0
# 4   Shares in UK drinks and food firm Allied Dome...             260.0
#
#    number_of_types                                       stemmed_text  \
# 0            244.0   quarterli profit at US media giant timewarn j...
# 1            230.0   the dollar ha hit it highest level against th...
# 2            168.0   the owner of embattl russian oil giant yuko a...
# 3            256.0   british airway ha blame high fuel price for a...
# 4            178.0   share in UK drink and food firm alli domecq h...
#
#                                             POS_tags  \
# 0  ['_SP', 'NNP', 'NNS', 'IN', 'NNP', 'NNS', 'NN'...
# 1  ['_SP', 'DT', 'NN', 'VBZ', 'VBN', 'PRP$', 'JJS...
# 2  ['_SP', 'DT', 'NNS', 'IN', 'VBN', 'JJ', 'NN', ...
# 3  ['_SP', 'NNP', 'NNP', 'VBZ', 'VBN', 'JJ', 'NN'...
# 4  ['_SP', 'NNP', 'IN', 'NNP', 'NNS', 'CC', 'NN',...
#
#                                                  POS  nouns  adjectives  verb
# 0  high fourth own fourth underlying exceptional ...   74.0        22.0   1.0
# 1  late recent sanguine current current next shar...   66.0        30.0   9.0
# 2  Russian former similar foreign Legal such real...   48.0        12.0   3.0
# 3  high pre - tax chief respectable third full la...   77.0        31.0   2.0
# 4  French last major global top other Last LVMH b...   42.0        13.0   2.0

# %%
df.shape
# Out:
# (2225, 12)

# %%
import re

def tokenize(doc):
    return re.findall('\w+', doc)

# %%
from nltk.corpus import stopwords

english_stop_words = stopwords.words('english')
#english_stop_words

# %% [markdown]
# # TSNE

# %% [markdown]
# ## TSNE (Davor)

# %%
# from sklearn.feature_extraction.text import CountVectorizer
# from sklearn.feature_extraction.text import TfidfVectorizer
# #from nltk.corpus import stopwords

# #english_stop_words = stopwords.words('english')

# cv = CountVectorizer(max_features = 2000,
#                      min_df = 10,
#                      max_df = 300,
#                      stop_words = 'english')

# cv.fit(df['POS'])

# results = cv.transform(df['POS'])
# features = cv.get_feature_names()

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
from yellowbrick.text import TSNEVisualizer

tf_idf_vectorizor = TfidfVectorizer(max_features=1000,
                                    stop_words='english')
tf_idf = tf_idf_vectorizor.fit_transform(df.content)
tf_idf_norm = normalize(tf_idf)
tf_idf_array = tf_idf_norm.toarray()

# %%
X_reduced = TruncatedSVD(n_components = 7, random_state = 0).fit_transform(tf_idf_array)

# %%
perplexity = [50]
for p in perplexity:
    X_embedded = TSNE(n_components=2, perplexity = p, n_iter= 1000, learning_rate = 10, verbose=2).fit_transform(X_reduced)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 2225 samples in 0.006s...
# [t-SNE] Computed neighbors for 2225 samples in 0.196s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2225
# [t-SNE] Computed conditional probabilities for sample 2000 / 2225
# [t-SNE] Computed conditional probabilities for sample 2225 / 2225
# [t-SNE] Mean sigma: 0.064332
# [t-SNE] Computed conditional probabilities in 0.221s
# [t-SNE] Iteration 50: error = 74.1803970, gradient norm = 0.0000363 (50 iterations in 1.118s)
# [t-SNE] Iteration 100: error = 64.8281937, gradient norm = 0.0062964 (50 iterations in 1.106s)
# [t-SNE] Iteration 150: error = 62.0064240, gradient norm = 0.0005446 (50 iterations in 1.070s)
# [t-SNE] Iteration 200: error = 61.8472862, gradient norm = 0.0001488 (50 iterations in 1.293s)
# [t-SNE] Iteration 250: error = 61.8304291, gradient norm = 0.0000661 (50 iterations in 1.424s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 61.830429
# [t-SNE] Iteration 300: error = 1.8060752, gradient norm = 0.0053367 (50 iterations in 1.074s)
# [t-SNE] Iteration 350: error = 1.3449039, gradient norm = 0.0022852 (50 iterations in 1.252s)
# [t-SNE] Iteration 400: error = 1.1476434, gradient norm = 0.0013454 (50 iterations in 1.171s)
# [t-SNE] Iteration 450: error = 1.0401797, gradient norm = 0.0008953 (50 iterations in 1.124s)
# [t-SNE] Iteration 500: error = 0.9735608, gradient norm = 0.0006441 (50 iterations in 1.057s)
# [t-SNE] Iteration 550: error = 0.9288105, gradient norm = 0.0004871 (50 iterations in 1.069s)
# [t-SNE] Iteration 600: error = 0.8971937, gradient norm = 0.0003861 (50 iterations in 1.072s)
# [t-SNE] Iteration 650: error = 0.8736519, gradient norm = 0.0003118 (50 iterations in 1.035s)
# [t-SNE] Iteration 700: error = 0.8556404, gradient norm = 0.0002597 (50 iterations in 1.060s)
# [t-SNE] Iteration 750: error = 0.8416340, gradient norm = 0.0002188 (50 iterations in 1.055s)
# [t-SNE] Iteration 800: error = 0.8305318, gradient norm = 0.0001908 (50 iterations in 1.052s)
# [t-SNE] Iteration 850: error = 0.8213554, gradient norm = 0.0001653 (50 iterations in 1.052s)
# [t-SNE] Iteration 900: error = 0.8141395, gradient norm = 0.0001458 (50 iterations in 1.051s)
# [t-SNE] Iteration 950: error = 0.8081506, gradient norm = 0.0001279 (50 iterations in 1.051s)
# [t-SNE] Iteration 1000: error = 0.8026746, gradient norm = 0.0001168 (50 iterations in 1.052s)
# [t-SNE] KL divergence after 1000 iterations: 0.802675

# %%
kmeans = KMeans(n_clusters=5, max_iter=600, algorithm = 'auto')
fitted = kmeans.fit(X_embedded)
prediction = kmeans.predict(X_embedded)
prediction
# Out:
# array([4, 4, 4, ..., 0, 0, 0])

# %%
plt.figure(figsize=(7,5))
plt.scatter(X_embedded[:, 0], X_embedded[:, 1], c=prediction, s=70, cmap='viridis')

plt.title('TSNE')
#plt.savefig('K_Means/TSNE_K-Means_POS.png', bbox_inches = "tight")
# Out:
# Text(0.5, 1.0, 'TSNE')

# %%
markers = ('o', 'v', '^', 's', 'p', '*','d', 'P', 'X')
plt.figure(figsize=(15,10))
sns.scatterplot(X_embedded[:, 0], X_embedded[:, 1],hue=prediction, style=df.category, markers=markers, palette=sns.color_palette("hls", len(np.unique(prediction))))

plt.title('TSNE')
#plt.savefig('../../Bilder/KMeans/kmeans_tsne_categorymarker_stemming_5_Cluster.png', bbox_inches = "tight")
# Out:
# Text(0.5, 1.0, 'TSNE')

# %% [markdown]
# ## TSNE (danach)

# %%
import pandas as pd
import numpy as np
from copy import deepcopy
from matplotlib import pyplot as plt
# %matplotlib inline
import itertools
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering, KMeans
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.spatial.distance import squareform
from sklearn.preprocessing import normalize
from sklearn.metrics import pairwise_distances
from sklearn import manifold
from sklearn.mixture import GaussianMixture, BayesianGaussianMixture 
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from yellowbrick.text import TSNEVisualizer, UMAPVisualizer

# %%
def tfidf(data):
    tf_idf_vectorizor = TfidfVectorizer(max_features=3000,
                                        stop_words='english',
                                        analyzer='word')
    tf_idf = tf_idf_vectorizor.fit_transform(data)
    tf_idf_norm = normalize(tf_idf)
    tf_idf_array = tf_idf_norm.toarray()
    return tf_idf_array

# %%
def visualise_TSNE(Y, hue, style, title, perplexity=50, path=None):
    X_reduced = TruncatedSVD(n_components=10, random_state=0).fit_transform(tf_idf_array)
    X_embedded = TSNE(n_components=2, perplexity=perplexity, n_iter=1000,learning_rate=10, verbose=2).fit_transform(X_reduced)
        
    markers = ('o', 'v', '^', 's', 'p', '*','d', 'P', 'X')
    plt.figure(figsize=(15,10))
    sns.set_style("white")
    sns.scatterplot(X_embedded[:, 0], X_embedded[:, 1],hue=hue, style=style, markers=markers, palette=sns.color_palette("hls", len(np.unique(hue))))
    plt.title(title)
    if path is not None:
        plt.savefig(path, bbox_inches = "tight")

# %%
# def compute_TSNE(text):
#     tsne = TSNE(n_components=2, perplexity = p, n_iter= 1000, learning_rate = 10, verbose=2)
#     Y = tsne.fit_transform(text)
#     return Y

# %%
tf_idf_array = tfidf(df.content)

# %%
kmeans = KMeans(n_clusters=5, max_iter=600, algorithm = 'auto')
fitted = kmeans.fit(tf_idf_array)
prediction = kmeans.predict(tf_idf_array)

# %%
X_reduced = TruncatedSVD(n_components=10, random_state=0).fit_transform(tf_idf_array)

# %%
# perplexity = [5, 10, 20, 30, 40, 50, 60 ,80,100]
perplexity = [50]
for p in perplexity:
    X_embedded = TSNE(n_components=2, perplexity=p, n_iter=1000,learning_rate=10, verbose=2).fit_transform(X_reduced)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 2225 samples in 0.009s...
# [t-SNE] Computed neighbors for 2225 samples in 0.226s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2225
# [t-SNE] Computed conditional probabilities for sample 2000 / 2225
# [t-SNE] Computed conditional probabilities for sample 2225 / 2225
# [t-SNE] Mean sigma: 0.063719
# [t-SNE] Computed conditional probabilities in 0.253s
# [t-SNE] Iteration 50: error = 74.0793991, gradient norm = 0.0000351 (50 iterations in 1.063s)
# [t-SNE] Iteration 100: error = 63.3022957, gradient norm = 0.0048845 (50 iterations in 0.991s)
# [t-SNE] Iteration 150: error = 60.2673912, gradient norm = 0.0011517 (50 iterations in 0.953s)
# [t-SNE] Iteration 200: error = 59.8264160, gradient norm = 0.0004534 (50 iterations in 1.020s)
# [t-SNE] Iteration 250: error = 59.6890488, gradient norm = 0.0002397 (50 iterations in 1.032s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 59.689049
# [t-SNE] Iteration 300: error = 1.6775889, gradient norm = 0.0053025 (50 iterations in 1.017s)
# [t-SNE] Iteration 350: error = 1.2107894, gradient norm = 0.0023383 (50 iterations in 1.006s)
# [t-SNE] Iteration 400: error = 1.0078514, gradient norm = 0.0013462 (50 iterations in 0.979s)
# [t-SNE] Iteration 450: error = 0.8988596, gradient norm = 0.0008869 (50 iterations in 1.015s)
# [t-SNE] Iteration 500: error = 0.8319201, gradient norm = 0.0006368 (50 iterations in 0.980s)
# [t-SNE] Iteration 550: error = 0.7879673, gradient norm = 0.0004835 (50 iterations in 0.986s)
# [t-SNE] Iteration 600: error = 0.7563678, gradient norm = 0.0003850 (50 iterations in 0.998s)
# [t-SNE] Iteration 650: error = 0.7328664, gradient norm = 0.0003108 (50 iterations in 1.007s)
# [t-SNE] Iteration 700: error = 0.7154580, gradient norm = 0.0002555 (50 iterations in 0.980s)
# [t-SNE] Iteration 750: error = 0.7015589, gradient norm = 0.0002179 (50 iterations in 1.080s)
# [t-SNE] Iteration 800: error = 0.6907610, gradient norm = 0.0001921 (50 iterations in 1.230s)
# [t-SNE] Iteration 850: error = 0.6816392, gradient norm = 0.0001700 (50 iterations in 1.126s)
# [t-SNE] Iteration 900: error = 0.6744558, gradient norm = 0.0001493 (50 iterations in 1.236s)
# [t-SNE] Iteration 950: error = 0.6681584, gradient norm = 0.0001357 (50 iterations in 1.111s)
# [t-SNE] Iteration 1000: error = 0.6632192, gradient norm = 0.0001231 (50 iterations in 1.052s)
# [t-SNE] KL divergence after 1000 iterations: 0.663219

# %%
visualise_TSNE(tf_idf_array, df.category, prediction,'TSNE', perplexity=50)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 2225 samples in 0.006s...
# [t-SNE] Computed neighbors for 2225 samples in 0.229s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2225
# [t-SNE] Computed conditional probabilities for sample 2000 / 2225
# [t-SNE] Computed conditional probabilities for sample 2225 / 2225
# [t-SNE] Mean sigma: 0.063719
# [t-SNE] Computed conditional probabilities in 0.224s
# [t-SNE] Iteration 50: error = 74.0793915, gradient norm = 0.0000639 (50 iterations in 1.061s)
# [t-SNE] Iteration 100: error = 62.9598083, gradient norm = 0.0052850 (50 iterations in 1.012s)
# [t-SNE] Iteration 150: error = 60.0442848, gradient norm = 0.0009467 (50 iterations in 0.959s)
# [t-SNE] Iteration 200: error = 59.6941833, gradient norm = 0.0003640 (50 iterations in 1.024s)
# [t-SNE] Iteration 250: error = 59.5835495, gradient norm = 0.0002278 (50 iterations in 0.968s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 59.583549
# [t-SNE] Iteration 300: error = 1.6798033, gradient norm = 0.0052703 (50 iterations in 0.991s)
# [t-SNE] Iteration 350: error = 1.2126751, gradient norm = 0.0023282 (50 iterations in 0.964s)
# [t-SNE] Iteration 400: error = 1.0102313, gradient norm = 0.0013477 (50 iterations in 1.018s)
# [t-SNE] Iteration 450: error = 0.9004190, gradient norm = 0.0009049 (50 iterations in 1.004s)
# [t-SNE] Iteration 500: error = 0.8322281, gradient norm = 0.0006652 (50 iterations in 0.978s)
# [t-SNE] Iteration 550: error = 0.7870967, gradient norm = 0.0004900 (50 iterations in 0.986s)
# [t-SNE] Iteration 600: error = 0.7547905, gradient norm = 0.0003852 (50 iterations in 0.995s)
# [t-SNE] Iteration 650: error = 0.7314438, gradient norm = 0.0003136 (50 iterations in 1.003s)
# [t-SNE] Iteration 700: error = 0.7135584, gradient norm = 0.0002636 (50 iterations in 0.975s)
# [t-SNE] Iteration 750: error = 0.6992848, gradient norm = 0.0002227 (50 iterations in 0.994s)
# [t-SNE] Iteration 800: error = 0.6877712, gradient norm = 0.0001925 (50 iterations in 1.025s)
# [t-SNE] Iteration 850: error = 0.6788820, gradient norm = 0.0001726 (50 iterations in 1.019s)
# [t-SNE] Iteration 900: error = 0.6712750, gradient norm = 0.0001524 (50 iterations in 0.985s)
# [t-SNE] Iteration 950: error = 0.6653532, gradient norm = 0.0001383 (50 iterations in 0.993s)
# [t-SNE] Iteration 1000: error = 0.6601396, gradient norm = 0.0001306 (50 iterations in 0.988s)
# [t-SNE] KL divergence after 1000 iterations: 0.660140

# %% [markdown]
# # PCA

# %% [markdown]
# ## Code Einführungsseminar

# %%
max_features = 1000
vec = TfidfVectorizer(max_features=max_features, 
                      tokenizer=tokenize,
                      stop_words=english_stop_words,
                      use_idf=True)
X = vec.fit_transform(df.content) #vectorizer creates a sparse matrix. 
df1 = pd.DataFrame(X.todense(), #has to be converted to a dense matrix
                  index=df.category, 
                  columns=vec.get_feature_names())
df1
# Out:
#             0       000         1        10  100        11        12       13  \
# category
# business  0.0  0.046158  0.043863  0.048524  0.0  0.062370  0.000000  0.00000
# business  0.0  0.000000  0.075512  0.000000  0.0  0.000000  0.000000  0.00000
# business  0.0  0.000000  0.000000  0.000000  0.0  0.000000  0.000000  0.00000
# business  0.0  0.046088  0.087593  0.048450  0.0  0.062275  0.000000  0.06889
# business  0.0  0.000000  0.140355  0.077634  0.0  0.000000  0.000000  0.00000
# ...       ...       ...       ...       ...  ...       ...       ...      ...
# tech      0.0  0.079106  0.037586  0.000000  0.0  0.000000  0.000000  0.00000
# tech      0.0  0.033955  0.000000  0.035696  0.0  0.000000  0.000000  0.00000
# tech      0.0  0.000000  0.000000  0.000000  0.0  0.000000  0.000000  0.00000
# tech      0.0  0.000000  0.000000  0.000000  0.0  0.056663  0.054133  0.00000
# tech      0.0  0.009818  0.000000  0.041283  0.0  0.026531  0.000000  0.00000
#
#            14        15  ...     world  worth     would  wrong      year  \
# category                 ...
# business  0.0  0.000000  ...  0.000000    0.0  0.000000    0.0  0.119226
# business  0.0  0.000000  ...  0.000000    0.0  0.000000    0.0  0.025657
# business  0.0  0.000000  ...  0.000000    0.0  0.036230    0.0  0.000000
# business  0.0  0.000000  ...  0.040307    0.0  0.030419    0.0  0.178567
# business  0.0  0.000000  ...  0.000000    0.0  0.000000    0.0  0.047688
# ...       ...       ...  ...       ...    ...       ...    ...       ...
# tech      0.0  0.000000  ...  0.000000    0.0  0.026106    0.0  0.000000
# tech      0.0  0.000000  ...  0.029697    0.0  0.000000    0.0  0.000000
# tech      0.0  0.000000  ...  0.025147    0.0  0.018978    0.0  0.037135
# tech      0.0  0.000000  ...  0.000000    0.0  0.000000    0.0  0.054159
# tech      0.0  0.040894  ...  0.111621    0.0  0.045359    0.0  0.019019
#
#              years       yet      york  young     yukos
# category
# business  0.000000  0.000000  0.000000    0.0  0.000000
# business  0.000000  0.000000  0.120873    0.0  0.000000
# business  0.000000  0.000000  0.000000    0.0  0.585566
# business  0.000000  0.059416  0.000000    0.0  0.000000
# business  0.000000  0.095206  0.000000    0.0  0.000000
# ...            ...       ...       ...    ...       ...
# tech      0.000000  0.000000  0.000000    0.0  0.000000
# tech      0.000000  0.000000  0.000000    0.0  0.000000
# tech      0.000000  0.037068  0.000000    0.0  0.000000
# tech      0.000000  0.000000  0.000000    0.0  0.000000
# tech      0.051378  0.000000  0.000000    0.0  0.000000
#
# [2225 rows x 1000 columns]

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(df1)   
plt.figure(figsize=(12,8))
for category, coord in zip(df1.index, X_pca):
        plt.plot(coord[0], coord[1], 'o', color='blue')
        plt.text(coord[0], coord[1]+0.005, category)

# %% [markdown]
# ## Code Clusteringseminar

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import PCA
from yellowbrick.features import PCA

vec1 = TfidfVectorizer(tokenizer=tokenize,
                      stop_words=english_stop_words,
                      use_idf=True)

data1 = vec1.fit_transform(df.stemmed_text)

# %%
X_reduced1 = TruncatedSVD(n_components=10, random_state=0).fit_transform(data1)

# %%
perplexity = [50]
for p in perplexity:
    X_embedded1 = PCA(n_components=2, perplexity=p, n_iter=1000,learning_rate=10, verbose=2).fit_transform(X_reduced1)

# %%
kmeans = KMeans(n_clusters=10, max_iter=600, algorithm = 'auto')
fitted = kmeans.fit(X_embedded1)
prediction = kmeans.predict(X_embedded1)
prediction
# Out:
# array([2, 2, 9, ..., 3, 5, 4])

# %%
plt.figure(figsize=(7,5))
plt.scatter(X_embedded1[:, 0], X_embedded1[:, 1], c=prediction, s=70, cmap='viridis')

plt.title('PCA')
#plt.savefig('K_Means/TSNE_K-Means_POS.png', bbox_inches = "tight")
# Out:
# Text(0.5, 1.0, 'PCA')

# %%
markers = ('o', 'v', '^', 's', 'p', '*','d', 'P', 'X')
plt.figure(figsize=(15,10))
sns.scatterplot(X_embedded1[:, 0], X_embedded1[:, 1],hue=prediction, style=df.category, markers=markers, palette=sns.color_palette("hls", len(np.unique(prediction))))

plt.title('PCA')
#plt.savefig('../../Bilder/KMeans/kmeans_pca_content', bbox_inches = "tight")
# Out:
# Text(0.5, 1.0, 'PCA')

# %% [markdown]
# # UMAP

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

from yellowbrick.datasets import load_hobbies
from yellowbrick.text import UMAPVisualizer
import umap
import sklearn.cluster as cluster

# %%
vec2 = TfidfVectorizer(tokenizer=tokenize,
                       stop_words=english_stop_words,
                       use_idf=True)

data2 = vec2.fit_transform(df.content)


#tfidf = TfidfVectorizer()
#data = df[:100]
#docs = tfidf.fit_transform(df.content)

# %%
kmeans_labels = cluster.KMeans(n_clusters=10, max_iter=600, algorithm='auto').fit_predict(data2)

# %%
standard_embedding = umap.UMAP(random_state=42).fit_transform(data2)

plt.figure(figsize=(15,10))
sns.scatterplot(standard_embedding[:, 0], y=standard_embedding[:, 1], hue=kmeans_labels, palette=sns.hls_palette(n_colors=len(np.unique(kmeans_labels)), l=0.45, s=.6))
plt.title('UMAP')
plt.legend()
#plt.savefig('../../Bilder/KMeans/UMAP_kmeans_content.png')
plt.show()

# %%
# tune parameters
improved_embedding = umap.UMAP(n_neighbors=30, min_dist=0.0, n_components=2, random_state=42).fit_transform(data2)

plt.figure(figsize=(15,10))
sns.scatterplot(improved_embedding[:, 0], y=improved_embedding[:, 1], hue=kmeans_labels, palette=sns.hls_palette(n_colors=len(np.unique(kmeans_labels)), l=0.45, s=.6))
plt.title('UMAP on raw text')
plt.legend()
#plt.savefig('improved_UMAP_kmeans_text.png')
plt.show()
